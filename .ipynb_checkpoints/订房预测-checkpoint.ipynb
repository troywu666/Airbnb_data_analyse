# %% [markdown]
# # Data Exploring

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import sklearn as sk
# %matplotlib inline
import datetime
import os
import seaborn as sns

# %%
train = pd.read_csv("train_users_2.csv")
test = pd.read_csv("test_users.csv")

# %%
train.head()
# Out:
#            id date_account_created  timestamp_first_active date_first_booking  \
# 0  gxn3p5htnn           2010-06-28          20090319043255                NaN
# 1  820tgsjxq7           2011-05-25          20090523174809                NaN
# 2  4ft3gnwmtx           2010-09-28          20090609231247         2010-08-02
# 3  bjjt8pjhuk           2011-12-05          20091031060129         2012-09-08
# 4  87mebub9p4           2010-09-14          20091208061105         2010-02-18
#
#       gender   age signup_method  signup_flow language affiliate_channel  \
# 0  -unknown-   NaN      facebook            0       en            direct
# 1       MALE  38.0      facebook            0       en               seo
# 2     FEMALE  56.0         basic            3       en            direct
# 3     FEMALE  42.0      facebook            0       en            direct
# 4  -unknown-  41.0         basic            0       en            direct
#
#   affiliate_provider first_affiliate_tracked signup_app first_device_type  \
# 0             direct               untracked        Web       Mac Desktop
# 1             google               untracked        Web       Mac Desktop
# 2             direct               untracked        Web   Windows Desktop
# 3             direct               untracked        Web       Mac Desktop
# 4             direct               untracked        Web       Mac Desktop
#
#   first_browser country_destination
# 0        Chrome                 NDF
# 1        Chrome                 NDF
# 2            IE                  US
# 3       Firefox               other
# 4        Chrome                  US

# %%
test.head()
# Out:
#            id date_account_created  timestamp_first_active  \
# 0  5uwns89zht           2014-07-01          20140701000006
# 1  jtl0dijy2j           2014-07-01          20140701000051
# 2  xx0ulgorjt           2014-07-01          20140701000148
# 3  6c6puo6ix0           2014-07-01          20140701000215
# 4  czqhjk3yfe           2014-07-01          20140701000305
#
#    date_first_booking     gender   age signup_method  signup_flow language  \
# 0                 NaN     FEMALE  35.0      facebook            0       en
# 1                 NaN  -unknown-   NaN         basic            0       en
# 2                 NaN  -unknown-   NaN         basic            0       en
# 3                 NaN  -unknown-   NaN         basic            0       en
# 4                 NaN  -unknown-   NaN         basic            0       en
#
#   affiliate_channel affiliate_provider first_affiliate_tracked signup_app  \
# 0            direct             direct               untracked      Moweb
# 1            direct             direct               untracked      Moweb
# 2            direct             direct                  linked        Web
# 3            direct             direct                  linked        Web
# 4            direct             direct               untracked        Web
#
#   first_device_type  first_browser
# 0            iPhone  Mobile Safari
# 1            iPhone  Mobile Safari
# 2   Windows Desktop         Chrome
# 3   Windows Desktop             IE
# 4       Mac Desktop         Safari

# %%
print(train.info(),'\n',test.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 213451 entries, 0 to 213450
# Data columns (total 16 columns):
# id                         213451 non-null object
# date_account_created       213451 non-null object
# timestamp_first_active     213451 non-null int64
# date_first_booking         88908 non-null object
# gender                     213451 non-null object
# age                        125461 non-null float64
# signup_method              213451 non-null object
# signup_flow                213451 non-null int64
# language                   213451 non-null object
# affiliate_channel          213451 non-null object
# affiliate_provider         213451 non-null object
# first_affiliate_tracked    207386 non-null object
# signup_app                 213451 non-null object
# first_device_type          213451 non-null object
# first_browser              213451 non-null object
# country_destination        213451 non-null object
# dtypes: float64(1), int64(2), object(13)
# memory usage: 26.1+ MB
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 62096 entries, 0 to 62095
# Data columns (total 15 columns):
# id                         62096 non-null object
# date_account_created       62096 non-null object
# timestamp_first_active     62096 non-null int64
# date_first_booking         0 non-null float64
# gender                     62096 non-null object
# age                        33220 non-null float64
# signup_method              62096 non-null object
# signup_flow                62096 non-null int64
# language                   62096 non-null object
# affiliate_channel          62096 non-null object
# affiliate_provider         62096 non-null object
# first_affiliate_tracked    62076 non-null object
# signup_app                 62096 non-null object
# first_device_type          62096 non-null object
# first_browser              62096 non-null object
# dtypes: float64(2), int64(2), object(11)
# memory usage: 7.1+ MB
# None
#  None

# %%
print(train.isnull().sum(),'\n',test.isnull().sum())
# Out:
# id                              0
# date_account_created            0
# timestamp_first_active          0
# date_first_booking         124543
# gender                          0
# age                         87990
# signup_method                   0
# signup_flow                     0
# language                        0
# affiliate_channel               0
# affiliate_provider              0
# first_affiliate_tracked      6065
# signup_app                      0
# first_device_type               0
# first_browser                   0
# country_destination             0
# dtype: int64
#  id                             0
# date_account_created           0
# timestamp_first_active         0
# date_first_booking         62096
# gender                         0
# age                        28876
# signup_method                  0
# signup_flow                    0
# language                       0
# affiliate_channel              0
# affiliate_provider             0
# first_affiliate_tracked       20
# signup_app                     0
# first_device_type              0
# first_browser                  0
# dtype: int64

# %%
print(train.shape,test.shape)
# Out:
# (213451, 16) (62096, 15)

# %% [markdown]
# ## Explore Each Feature

# %% [markdown]
# ### date_account_created

# %%
dac_train=train.date_account_created.value_counts()
dac_test=test.date_account_created.value_counts()
print('train.date_account_created:',
      dac_train.describe(),
      'test.date_account_created:\n',
      dac_test.describe())
# Out:
# train.date_account_created: count    1634.000000
# mean      130.630967
# std       139.327895
# min         1.000000
# 25%        15.000000
# 50%        79.000000
# 75%       201.000000
# max       674.000000
# Name: date_account_created, dtype: float64 test.date_account_created:
#  count      92.000000
# mean      674.956522
# std       122.568116
# min       401.000000
# 25%       606.750000
# 50%       662.000000
# 75%       739.000000
# max      1105.000000
# Name: date_account_created, dtype: float64

# %%
dac_train_data=pd.to_datetime(dac_train.index)
dac_test_data=pd.to_datetime(dac_test.index)

dac_train_day=dac_train_data-dac_train_data.min()
dac_test_day=dac_test_data-dac_train_data.min()

print(dac_train_day,'\n',dac_test_day)
# Out:
# TimedeltaIndex(['1593 days', '1635 days', '1636 days', '1600 days',
#                 '1594 days', '1601 days', '1614 days', '1627 days',
#                 '1622 days', '1608 days',
#                 ...
#                  '100 days',   '44 days',   '67 days',    '7 days',
#                  '168 days',    '0 days',    '1 days',   '27 days',
#                   '22 days',   '90 days'],
#                dtype='timedelta64[ns]', length=1634, freq=None)
#  TimedeltaIndex(['1664 days', '1663 days', '1658 days', '1665 days',
#                 '1659 days', '1662 days', '1699 days', '1698 days',
#                 '1670 days', '1678 days', '1671 days', '1684 days',
#                 '1683 days', '1700 days', '1677 days', '1669 days',
#                 '1657 days', '1666 days', '1672 days', '1719 days',
#                 '1686 days', '1691 days', '1679 days', '1713 days',
#                 '1661 days', '1680 days', '1685 days', '1706 days',
#                 '1676 days', '1697 days', '1727 days', '1660 days',
#                 '1668 days', '1726 days', '1733 days', '1673 days',
#                 '1705 days', '1732 days', '1693 days', '1667 days',
#                 '1711 days', '1707 days', '1681 days', '1690 days',
#                 '1694 days', '1649 days', '1692 days', '1656 days',
#                 '1688 days', '1712 days', '1725 days', '1721 days',
#                 '1687 days', '1643 days', '1702 days', '1718 days',
#                 '1714 days', '1675 days', '1655 days', '1644 days',
#                 '1648 days', '1701 days', '1703 days', '1720 days',
#                 '1708 days', '1695 days', '1650 days', '1689 days',
#                 '1651 days', '1696 days', '1722 days', '1682 days',
#                 '1715 days', '1642 days', '1716 days', '1704 days',
#                 '1674 days', '1710 days', '1730 days', '1709 days',
#                 '1724 days', '1728 days', '1723 days', '1717 days',
#                 '1729 days', '1652 days', '1731 days', '1647 days',
#                 '1653 days', '1645 days', '1646 days', '1654 days'],
#                dtype='timedelta64[ns]', freq=None)

# %%
dac_train_day.days
# Out:
# Int64Index([1593, 1635, 1636, 1600, 1594, 1601, 1614, 1627, 1622, 1608,
#             ...
#              100,   44,   67,    7,  168,    0,    1,   27,   22,   90],
#            dtype='int64', length=1634)

# %%
plt.scatter(dac_train_day.days,dac_train.values,color='r',label='train_datasets')
plt.scatter(dac_test_day.days,dac_test.values,color='b',label='test_datasets')
plt.xlabel("Days")
plt.ylabel("The number of accounts created")
plt.title('Accounts created vs day')
# Out:
# Text(0.5, 1.0, 'Accounts created vs day')

# %% [markdown]
# ### timestamp_first_active

# %%
tfa_train=train.timestamp_first_active.map(lambda x: datetime.datetime.strptime(str(x),'%Y%m%d%H%M%S'))
tfa_train.head()
# Out:
# 0   2009-03-19 04:32:55
# 1   2009-05-23 17:48:09
# 2   2009-06-09 23:12:47
# 3   2009-10-31 06:01:29
# 4   2009-12-08 06:11:05
# Name: timestamp_first_active, dtype: datetime64[ns]

# %%
tfa_train.describe()
# Out:
# count                  213451
# unique                 213451
# top       2013-07-01 05:26:34
# freq                        1
# first     2009-03-19 04:32:55
# last      2014-06-30 23:58:24
# Name: timestamp_first_active, dtype: object

# %% [markdown]
# ### age

# %%
train.age.isnull().sum()
# Out:
# 87990

# %%
age_train=[train.age.isnull().sum(),
           train.query('age<15').age.shape[0],
           train.query('age>=15&age<90').age.shape[0],
           train.query('age>=90').age.shape[0]]
age_test=[test.age.isnull().sum(),
          test.query('age<15').age.shape[0],
          test.query('age>=15&age<90').age.shape[0],
          test.query('age>=90').age.shape[0]]

columns=['Null','age<15','15<=age<90','age>90']

fig,(ax1,ax2)=plt.subplots(1,2,sharex=True,sharey=True,figsize=(10,5))
sns.barplot(columns,age_train,ax=ax1)
sns.barplot(columns,age_test,ax=ax2)
ax1.set_title('train datasets')
ax2.set_title('test datasets')
ax1.set_ylabel('counts')
# Out:
# Text(0, 0.5, 'counts')

# %% [markdown]
# ### Categorical features

# %%
cate_feats = ['gender', 
             'signup_method', 
             'signup_flow', 
             'language', 
             'affiliate_channel', 
             'affiliate_provider', 
             'first_affiliate_tracked', 
             'signup_app', 
             'first_device_type', 
             'first_browser']

def feature_barplot(feature, df_train = train, df_test = test, figsize=(10,5), rot = 90, saveimg = False):
    
    feat_train = df_train[feature].value_counts()
    feat_test = df_test[feature].value_counts()
    
    fig_feature, (ax1,ax2) = plt.subplots(1,2,sharex=True, sharey = True, figsize = figsize)

    sns.barplot(feat_train.index.values, feat_train.values, ax = ax1)
    sns.barplot(feat_test.index.values, feat_test.values, ax = ax2)
    
    ax1.set_xticklabels(ax1.xaxis.get_majorticklabels(), rotation = rot)
    ax2.set_xticklabels(ax1.xaxis.get_majorticklabels(), rotation = rot)

    ax1.set_title(feature + ' of train dataset')
    ax2.set_title(feature + ' of test dataset')
    ax1.set_ylabel('counts')
    
    plt.tight_layout()
    
for feat in cate_feats:
    feature_barplot(feature = feat)

# %% [markdown]
# # Featur Enginnering

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import sklearn as sk
#import pickle
import datetime
from datetime import date
#import os
import seaborn as sns
from sklearn.preprocessing import *
from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import StratifiedShuffleSplit
import seaborn as sns
# %matplotlib inline

# %%
df_session=pd.read_csv('sessions.csv')
df_session
# Out:
#             user_id                 action action_type  \
# 0        d1mm9tcy42                 lookup         NaN
# 1        d1mm9tcy42         search_results       click
# 2        d1mm9tcy42                 lookup         NaN
# 3        d1mm9tcy42         search_results       click
# 4        jpmpj40cvk                 lookup         NaN
# 5        jpmpj40cvk         search_results       click
# 6        jpmpj40cvk         search_results       click
# 7        jpmpj40cvk         search_results       click
# 8        jpmpj40cvk         search_results       click
# 9        jpmpj40cvk  ajax_refresh_subtotal       click
# 10       jpmpj40cvk                   show       click
# 11       jpmpj40cvk                 lookup         NaN
# 12       jpmpj40cvk         search_results       click
# 13       jpmpj40cvk                 lookup        view
# 14       jpmpj40cvk         search_results       click
# 15       jpmpj40cvk                 lookup       click
# 16       jpmpj40cvk         search_results       click
# 17       jpmpj40cvk  ajax_refresh_subtotal       click
# 18       jpmpj40cvk                   show         NaN
# 19       jpmpj40cvk            personalize        data
# 20       jpmpj40cvk                   show        view
# 21       jpmpj40cvk                   show        view
# 22       jpmpj40cvk  ajax_refresh_subtotal       click
# 23       jpmpj40cvk                   show         NaN
# 24       jpmpj40cvk            personalize        data
# 25       jpmpj40cvk                   show        view
# 26       jpmpj40cvk                  index        view
# 27       jpmpj40cvk       similar_listings        data
# 28       jpmpj40cvk            personalize        data
# 29       7jxkifmj7m          confirm_email       click
# ...             ...                    ...         ...
# 1048545  piwqqc0x1m         search_results       click
# 1048546  piwqqc0x1m         search_results       click
# 1048547  piwqqc0x1m                   show        view
# 1048548  piwqqc0x1m                   show         NaN
# 1048549  piwqqc0x1m                   show         NaN
# 1048550  piwqqc0x1m            personalize        data
# 1048551  piwqqc0x1m            personalize        data
# 1048552  piwqqc0x1m  ajax_refresh_subtotal       click
# 1048553  piwqqc0x1m       similar_listings        data
# 1048554  piwqqc0x1m                  index        view
# 1048555  piwqqc0x1m                   show        view
# 1048556  piwqqc0x1m                   show        view
# 1048557  piwqqc0x1m               listings   -unknown-
# 1048558  piwqqc0x1m  ajax_refresh_subtotal       click
# 1048559  piwqqc0x1m       similar_listings        data
# 1048560  piwqqc0x1m                   show        view
# 1048561  piwqqc0x1m            personalize        data
# 1048562  piwqqc0x1m                   show         NaN
# 1048563  piwqqc0x1m  ajax_refresh_subtotal       click
# 1048564  piwqqc0x1m         search_results       click
# 1048565  piwqqc0x1m                   show        view
# 1048566  piwqqc0x1m                   show        view
# 1048567  piwqqc0x1m       similar_listings        data
# 1048568  piwqqc0x1m                   show         NaN
# 1048569  em1hg8l6k8                   show        view
# 1048570  em1hg8l6k8            personalize        data
# 1048571  em1hg8l6k8                   show        view
# 1048572  em1hg8l6k8            personalize        data
# 1048573  em1hg8l6k8       similar_listings        data
# 1048574  em1hg8l6k8                  index        view
#
#                        action_detail      device_type  secs_elapsed
# 0                                NaN  Windows Desktop         319.0
# 1                view_search_results  Windows Desktop       67753.0
# 2                                NaN  Windows Desktop         301.0
# 3                view_search_results  Windows Desktop       22141.0
# 4                                NaN  Windows Desktop         957.0
# 5                view_search_results  Windows Desktop         965.0
# 6                view_search_results  Windows Desktop        1021.0
# 7                view_search_results  Windows Desktop         938.0
# 8                view_search_results  Windows Desktop        2702.0
# 9        change_trip_characteristics  Windows Desktop         674.0
# 10               view_search_results  Windows Desktop          52.0
# 11                               NaN  Windows Desktop         826.0
# 12               view_search_results  Windows Desktop        2470.0
# 13               view_search_results  Windows Desktop         309.0
# 14               view_search_results  Windows Desktop        1548.0
# 15       change_trip_characteristics  Windows Desktop         374.0
# 16               view_search_results  Windows Desktop       24499.0
# 17       change_trip_characteristics  Windows Desktop         373.0
# 18                               NaN  Windows Desktop          78.0
# 19           wishlist_content_update  Windows Desktop         759.0
# 20                                p3  Windows Desktop         433.0
# 21                                p3  Windows Desktop      525040.0
# 22       change_trip_characteristics  Windows Desktop        1607.0
# 23                               NaN  Windows Desktop         167.0
# 24           wishlist_content_update  Windows Desktop         657.0
# 25                                p3  Windows Desktop       32965.0
# 26               view_search_results  Windows Desktop       24670.0
# 27                  similar_listings  Windows Desktop         193.0
# 28           wishlist_content_update  Windows Desktop        1193.0
# 29                confirm_email_link  Windows Desktop     1198189.0
# ...                              ...              ...           ...
# 1048545          view_search_results  Windows Desktop       94424.0
# 1048546          view_search_results  Windows Desktop       37260.0
# 1048547                           p3  Windows Desktop      142048.0
# 1048548                          NaN  Windows Desktop        1531.0
# 1048549                          NaN  Windows Desktop          17.0
# 1048550      wishlist_content_update  Windows Desktop        1144.0
# 1048551      wishlist_content_update  Windows Desktop          17.0
# 1048552  change_trip_characteristics  Windows Desktop         935.0
# 1048553             similar_listings  Windows Desktop         120.0
# 1048554          view_search_results  Windows Desktop       31964.0
# 1048555                           p3  Windows Desktop       29940.0
# 1048556                           p3  Windows Desktop       18525.0
# 1048557                    -unknown-  Windows Desktop         155.0
# 1048558  change_trip_characteristics  Windows Desktop         567.0
# 1048559             similar_listings  Windows Desktop          87.0
# 1048560                           p3  Windows Desktop       89106.0
# 1048561      wishlist_content_update  Windows Desktop        1389.0
# 1048562                          NaN  Windows Desktop          67.0
# 1048563  change_trip_characteristics  Windows Desktop        1225.0
# 1048564          view_search_results  Windows Desktop       70147.0
# 1048565                           p3  Windows Desktop       61159.0
# 1048566                           p3  Windows Desktop          52.0
# 1048567             similar_listings  Windows Desktop         241.0
# 1048568                          NaN  Windows Desktop        1248.0
# 1048569                           p3      Mac Desktop       32674.0
# 1048570      wishlist_content_update      Mac Desktop        1658.0
# 1048571                           p3      Mac Desktop        6941.0
# 1048572      wishlist_content_update      Mac Desktop        4161.0
# 1048573             similar_listings      Mac Desktop         166.0
# 1048574          view_search_results      Mac Desktop       11680.0
#
# [1048575 rows x 6 columns]

# %%
df_session['id']=df_session['user_id']
df_session.drop(['user_id'],axis=1)
# Out:
#                         action action_type                action_detail  \
# 0                       lookup         NaN                          NaN
# 1               search_results       click          view_search_results
# 2                       lookup         NaN                          NaN
# 3               search_results       click          view_search_results
# 4                       lookup         NaN                          NaN
# 5               search_results       click          view_search_results
# 6               search_results       click          view_search_results
# 7               search_results       click          view_search_results
# 8               search_results       click          view_search_results
# 9        ajax_refresh_subtotal       click  change_trip_characteristics
# 10                        show       click          view_search_results
# 11                      lookup         NaN                          NaN
# 12              search_results       click          view_search_results
# 13                      lookup        view          view_search_results
# 14              search_results       click          view_search_results
# 15                      lookup       click  change_trip_characteristics
# 16              search_results       click          view_search_results
# 17       ajax_refresh_subtotal       click  change_trip_characteristics
# 18                        show         NaN                          NaN
# 19                 personalize        data      wishlist_content_update
# 20                        show        view                           p3
# 21                        show        view                           p3
# 22       ajax_refresh_subtotal       click  change_trip_characteristics
# 23                        show         NaN                          NaN
# 24                 personalize        data      wishlist_content_update
# 25                        show        view                           p3
# 26                       index        view          view_search_results
# 27            similar_listings        data             similar_listings
# 28                 personalize        data      wishlist_content_update
# 29               confirm_email       click           confirm_email_link
# ...                        ...         ...                          ...
# 1048545         search_results       click          view_search_results
# 1048546         search_results       click          view_search_results
# 1048547                   show        view                           p3
# 1048548                   show         NaN                          NaN
# 1048549                   show         NaN                          NaN
# 1048550            personalize        data      wishlist_content_update
# 1048551            personalize        data      wishlist_content_update
# 1048552  ajax_refresh_subtotal       click  change_trip_characteristics
# 1048553       similar_listings        data             similar_listings
# 1048554                  index        view          view_search_results
# 1048555                   show        view                           p3
# 1048556                   show        view                           p3
# 1048557               listings   -unknown-                    -unknown-
# 1048558  ajax_refresh_subtotal       click  change_trip_characteristics
# 1048559       similar_listings        data             similar_listings
# 1048560                   show        view                           p3
# 1048561            personalize        data      wishlist_content_update
# 1048562                   show         NaN                          NaN
# 1048563  ajax_refresh_subtotal       click  change_trip_characteristics
# 1048564         search_results       click          view_search_results
# 1048565                   show        view                           p3
# 1048566                   show        view                           p3
# 1048567       similar_listings        data             similar_listings
# 1048568                   show         NaN                          NaN
# 1048569                   show        view                           p3
# 1048570            personalize        data      wishlist_content_update
# 1048571                   show        view                           p3
# 1048572            personalize        data      wishlist_content_update
# 1048573       similar_listings        data             similar_listings
# 1048574                  index        view          view_search_results
#
#              device_type  secs_elapsed          id
# 0        Windows Desktop         319.0  d1mm9tcy42
# 1        Windows Desktop       67753.0  d1mm9tcy42
# 2        Windows Desktop         301.0  d1mm9tcy42
# 3        Windows Desktop       22141.0  d1mm9tcy42
# 4        Windows Desktop         957.0  jpmpj40cvk
# 5        Windows Desktop         965.0  jpmpj40cvk
# 6        Windows Desktop        1021.0  jpmpj40cvk
# 7        Windows Desktop         938.0  jpmpj40cvk
# 8        Windows Desktop        2702.0  jpmpj40cvk
# 9        Windows Desktop         674.0  jpmpj40cvk
# 10       Windows Desktop          52.0  jpmpj40cvk
# 11       Windows Desktop         826.0  jpmpj40cvk
# 12       Windows Desktop        2470.0  jpmpj40cvk
# 13       Windows Desktop         309.0  jpmpj40cvk
# 14       Windows Desktop        1548.0  jpmpj40cvk
# 15       Windows Desktop         374.0  jpmpj40cvk
# 16       Windows Desktop       24499.0  jpmpj40cvk
# 17       Windows Desktop         373.0  jpmpj40cvk
# 18       Windows Desktop          78.0  jpmpj40cvk
# 19       Windows Desktop         759.0  jpmpj40cvk
# 20       Windows Desktop         433.0  jpmpj40cvk
# 21       Windows Desktop      525040.0  jpmpj40cvk
# 22       Windows Desktop        1607.0  jpmpj40cvk
# 23       Windows Desktop         167.0  jpmpj40cvk
# 24       Windows Desktop         657.0  jpmpj40cvk
# 25       Windows Desktop       32965.0  jpmpj40cvk
# 26       Windows Desktop       24670.0  jpmpj40cvk
# 27       Windows Desktop         193.0  jpmpj40cvk
# 28       Windows Desktop        1193.0  jpmpj40cvk
# 29       Windows Desktop     1198189.0  7jxkifmj7m
# ...                  ...           ...         ...
# 1048545  Windows Desktop       94424.0  piwqqc0x1m
# 1048546  Windows Desktop       37260.0  piwqqc0x1m
# 1048547  Windows Desktop      142048.0  piwqqc0x1m
# 1048548  Windows Desktop        1531.0  piwqqc0x1m
# 1048549  Windows Desktop          17.0  piwqqc0x1m
# 1048550  Windows Desktop        1144.0  piwqqc0x1m
# 1048551  Windows Desktop          17.0  piwqqc0x1m
# 1048552  Windows Desktop         935.0  piwqqc0x1m
# 1048553  Windows Desktop         120.0  piwqqc0x1m
# 1048554  Windows Desktop       31964.0  piwqqc0x1m
# 1048555  Windows Desktop       29940.0  piwqqc0x1m
# 1048556  Windows Desktop       18525.0  piwqqc0x1m
# 1048557  Windows Desktop         155.0  piwqqc0x1m
# 1048558  Windows Desktop         567.0  piwqqc0x1m
# 1048559  Windows Desktop          87.0  piwqqc0x1m
# 1048560  Windows Desktop       89106.0  piwqqc0x1m
# 1048561  Windows Desktop        1389.0  piwqqc0x1m
# 1048562  Windows Desktop          67.0  piwqqc0x1m
# 1048563  Windows Desktop        1225.0  piwqqc0x1m
# 1048564  Windows Desktop       70147.0  piwqqc0x1m
# 1048565  Windows Desktop       61159.0  piwqqc0x1m
# 1048566  Windows Desktop          52.0  piwqqc0x1m
# 1048567  Windows Desktop         241.0  piwqqc0x1m
# 1048568  Windows Desktop        1248.0  piwqqc0x1m
# 1048569      Mac Desktop       32674.0  em1hg8l6k8
# 1048570      Mac Desktop        1658.0  em1hg8l6k8
# 1048571      Mac Desktop        6941.0  em1hg8l6k8
# 1048572      Mac Desktop        4161.0  em1hg8l6k8
# 1048573      Mac Desktop         166.0  em1hg8l6k8
# 1048574      Mac Desktop       11680.0  em1hg8l6k8
#
# [1048575 rows x 6 columns]

# %%
df_session.shape
# Out:
# (1048575, 7)

# %%
df_session.isnull().sum()
# Out:
# user_id            2797
# action             7873
# action_type      143097
# action_detail    143097
# device_type           0
# secs_elapsed      11067
# id                 2797
# dtype: int64

# %%
df_session.action=df_session.action.fillna('NAN')
df_session.action_type=df_session.action_type.fillna('NAN')
df_session.action_detail=df_session.action_detail.fillna('NAN')

# %%
act=dict(zip(*np.unique(df_session.action,return_counts=True)))
df_session.action=df_session.action.map(lambda x: 'OTHER' if act[x]<100 else x)
